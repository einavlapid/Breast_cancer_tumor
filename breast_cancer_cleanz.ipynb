# %%
# import matplotlib as plt
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sb
import warnings as datawarnings
datawarnings.filterwarnings('ignore')

# %% [markdown]
# # Data cleanzing
# **The dataset is clean, with no missing data. All variables are continuous numerical and do not necessitate normalization. Outlier detection and handling will be the next step**

# %%
df = pd.read_pickle('df_prep.pkl')
con_df = df.drop(columns=['diagnosis',"id"])
skewness_values = con_df.skew()

# %% [markdown]
# # Outlier detection and handling

# %%
def boxplot(con_df):
    for i, col in enumerate(con_df.columns):
            ax = plt.subplot(60, 3, i+1)
            sb.boxplot(data=con_df, x=col, ax=ax)
            plt.subplots_adjust(hspace = 0.7)
            plt.title('Box Plot: {}'.format(col), fontsize=15)
            plt.xlabel('{}'.format(col), fontsize=14)

# %%
def scatterplot(con_df):
    for i, col in enumerate(con_df.columns):
            ax = plt.subplot(60, 3, i+1)
            sb.scatterplot(x=con_df.index,y=con_df[col])
            plt.subplots_adjust(hspace = 0.7)
            plt.title('Scatter plot: {}'.format(col), fontsize=15)
            plt.xlabel('{}'.format(col), fontsize=14)

# %% [markdown]
# ## Outliers for parametric distribution
# ### The code identifies columns with near-normal (parametric) distributions and then creates boxplots and scatterplots to visualize these distributions and detect outliers.

# %%
# outliers for parametric distribution
para_columns = skewness_values[abs(skewness_values) <= 0.5].index.tolist()
plt.figure(figsize=(20,200))
boxplot(df[para_columns])

plt.figure(figsize=(20,200))
scatterplot(df[para_columns])

# %% [markdown]
# ### This code identify and optionally remove outliers from a dataset using the Z-score method, specifically for columns that follow a parametric distribution.

# %%
#  outliers
# identify outliers using z-score for parametric distribution
from scipy import stats
from scipy.stats import zscore

threshold = 2.5
for col in para_columns:
    z = np.abs(stats.zscore(df[col]))
    df2 = df.copy()
    df2 = df2[z < threshold]
    num_of_outliers = df[col].count() - df2[col].count()
    if  num_of_outliers > 0:
        percent_num_of_outliers = (num_of_outliers/df[col].count())*100
        p_value = stats.ks_2samp(df[col], df2[col])[1]
        correlation = df[col].corr(df['diagnosis'])
        correlation2 = df2[col].corr(df2['diagnosis'])
        correlation_diff = abs(correlation - correlation2)
        # corollation is the same, distribution changed, 
        remove_outlier =  (correlation_diff < 0.05) & (p_value < 0.05)
        if remove_outlier:
            df[col][z > threshold] = np.nan
        print(f"col: {col}, num of outliers: {num_of_outliers}, Percentage of outliers: {percent_num_of_outliers} %")
        print(f"p_value: {p_value}")
        print(f"original correlation: {correlation}, correlation after removing outliers: {correlation2},correlation changing: {correlation_diff}") 
        print(f"fill nan instaed of outlier: {remove_outlier}\n\n")
# Out:
# col: smoothness_mean, num of outliers: 9, Percentage of outliers: 1.5817223198594026 %
# p_value: 0.9999999738114437
# original correlation: 0.3585599650859315, correlation after removing outliers: 0.35867215267158675,correlation changing: 0.00011218758565523235
# fill nan instaed of outlier: False
#
#
# col: texture_worst, num of outliers: 8, Percentage of outliers: 1.4059753954305798 %
# p_value: 0.999999973163413
# original correlation: 0.4569028213967977, correlation after removing outliers: 0.45597500573446315,correlation changing: 0.0009278156623345746
# fill nan instaed of outlier: False
#
#
# col: smoothness_worst, num of outliers: 7, Percentage of outliers: 1.2302284710017575 %
# p_value: 0.9999999999999739
# original correlation: 0.4214648610664021, correlation after removing outliers: 0.42430511132383275,correlation changing: 0.0028402502574306765
# fill nan instaed of outlier: False
#
#
# col: concave points_worst, num of outliers: 3, Percentage of outliers: 0.5272407732864675 %
# p_value: 1.0
# original correlation: 0.7935660171412687, correlation after removing outliers: 0.7937843299038648,correlation changing: 0.00021831276259609567
# fill nan instaed of outlier: False

# %% [markdown]
# ### Conclusion:
# For all the columns analyzed (smoothness_mean, texture_worst, smoothness_worst, and concave_points_worst), the decision was made not to remove the outliers because they do not significantly affect the distribution or the correlation with the target variable.

# %% [markdown]
# ## Outliers for nonparametric distribution
# ### The code identifies columns with skewed (non-parametric) distributions and then creates boxplots and scatterplots to visualize these distributions and detect outliers.

# %%
#  outliers for nonparametric distribution
notpara_columns = skewness_values[abs(skewness_values) > 0.5].index.tolist()
plt.figure(figsize=(20,200))
boxplot(df[notpara_columns])

plt.figure(figsize=(20,200))
scatterplot(df[notpara_columns])

# %%
def treat_outliers(df, features):
    df_outliers = pd.DataFrame(index=df.index)
    for feature in features:
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df_outliers[feature] = ((df[feature] < lower_bound) | (df[feature] > upper_bound)).astype(int)
    return df_outliers

# %% [markdown]
# ### This code identifies outliers using the Interquartile Range (IQR) method for non-parametric columns in a dataset.

# %%
# identify outliers using IQR 
outliers_df = treat_outliers(df, notpara_columns)
for col in notpara_columns:
    df2 = df[(outliers_df[col] == 0)]
    num_of_outliers = df[col].count() - df2[col].count()
    if  num_of_outliers > 0:
        percent_num_of_outliers = (num_of_outliers/df[col].count())* 100
        p_value = stats.ks_2samp(df[col], df2[col])[1]
        correlation = df[col].corr(df['diagnosis'],method="spearman")
        correlation2 = df2[col].corr(df2['diagnosis'],method="spearman")
        correlation_diff = abs(correlation - correlation2)
        # corollation is the same, distribution changed 
        remove_outlier =  (correlation_diff < 0.05) & (p_value < 0.05)
        if remove_outlier:
            print("hi")
            df[col][(outliers_df[col] == 1)] = np.nan
        print(f"col: {col}, num of outliers: {num_of_outliers}, Percentage of outliers: {percent_num_of_outliers} %")
        print(f"p_value: {p_value}")
        print(f"original correlation: {correlation}, correlation after removing outliers: {correlation2},correlation changing: {correlation_diff}") 
        print(f"fill nan instaed of outlier: {remove_outlier}\n\n")
# Out:
# col: radius_mean, num of outliers: 14, Percentage of outliers: 2.460456942003515 %
# p_value: 0.9934323936117693
# original correlation: 0.7327849896210553, correlation after removing outliers: 0.7187086097357105,correlation changing: 0.014076379885344825
# fill nan instaed of outlier: False
#
#
# col: texture_mean, num of outliers: 7, Percentage of outliers: 1.2302284710017575 %
# p_value: 0.9999999998904686
# original correlation: 0.4619709203699609, correlation after removing outliers: 0.4591983257522409,correlation changing: 0.0027725946177200034
# fill nan instaed of outlier: False
#
#
# col: perimeter_mean, num of outliers: 13, Percentage of outliers: 2.2847100175746924 %
# p_value: 0.9975048738106226
# original correlation: 0.7484960094161621, correlation after removing outliers: 0.7363788426393386,correlation changing: 0.012117166776823507
# fill nan instaed of outlier: False
#
#
# col: area_mean, num of outliers: 25, Percentage of outliers: 4.393673110720562 %
# p_value: 0.6334749769689041
# original correlation: 0.7341224574055575, correlation after removing outliers: 0.7075972296582769,correlation changing: 0.02652522774728061
# fill nan instaed of outlier: False
#
#
# col: compactness_mean, num of outliers: 16, Percentage of outliers: 2.8119507908611596 %
# p_value: 0.9730375373652475
# original correlation: 0.6092883740075209, correlation after removing outliers: 0.5843699791735985,correlation changing: 0.02491839483392244
# fill nan instaed of outlier: False
#
#
# col: concavity_mean, num of outliers: 18, Percentage of outliers: 3.163444639718805 %
# p_value: 0.9298601453776189
# original correlation: 0.7333078827585809, correlation after removing outliers: 0.7326303315656717,correlation changing: 0.0006775511929092426
# fill nan instaed of outlier: False
#
#
# col: concave points_mean, num of outliers: 10, Percentage of outliers: 1.7574692442882252 %
# p_value: 0.9999804310693853
# original correlation: 0.777877465455518, correlation after removing outliers: 0.7699636036886245,correlation changing: 0.00791386176689346
# fill nan instaed of outlier: False
#
#
# col: symmetry_mean, num of outliers: 15, Percentage of outliers: 2.6362038664323375 %
# p_value: 0.9934754709320989
# original correlation: 0.3325674212195175, correlation after removing outliers: 0.3243089389964865,correlation changing: 0.008258482223030994
# fill nan instaed of outlier: False
#
#
# col: fractal_dimension_mean, num of outliers: 15, Percentage of outliers: 2.6362038664323375 %
# p_value: 0.9856955377061442
# original correlation: -0.025902934814889065, correlation after removing outliers: -0.023237617946476698,correlation changing: 0.0026653168684123672
# fill nan instaed of outlier: False
#
#
# col: radius_se, num of outliers: 38, Percentage of outliers: 6.6783831282952555 %
# p_value: 0.1622763159868495
# original correlation: 0.6169120556579272, correlation after removing outliers: 0.5583352488858413,correlation changing: 0.058576806772085876
# fill nan instaed of outlier: False
#
#
# col: texture_se, num of outliers: 20, Percentage of outliers: 3.5149384885764503 %
# p_value: 0.862841177783212
# original correlation: 0.01941889547771949, correlation after removing outliers: 0.03068098775097652,correlation changing: 0.01126209227325703
# fill nan instaed of outlier: False
#
#
# col: perimeter_se, num of outliers: 38, Percentage of outliers: 6.6783831282952555 %
# p_value: 0.1622763159868495
# original correlation: 0.6304113280281167, correlation after removing outliers: 0.5681045856169142,correlation changing: 0.06230674241120249
# fill nan instaed of outlier: False
#
#
# col: area_se, num of outliers: 65, Percentage of outliers: 11.423550087873462 %
# p_value: 0.0016733538179620397
# original correlation: 0.7141837178954084, correlation after removing outliers: 0.6201676826622876,correlation changing: 0.09401603523312074
# fill nan instaed of outlier: False
#
#
# col: smoothness_se, num of outliers: 30, Percentage of outliers: 5.272407732864675 %
# p_value: 0.4055933769976085
# original correlation: -0.05219309189048605, correlation after removing outliers: -0.008205440759212545,correlation changing: 0.04398765113127351
# fill nan instaed of outlier: False
#
#
# col: compactness_se, num of outliers: 28, Percentage of outliers: 4.92091388400703 %
# p_value: 0.49143742390333134
# original correlation: 0.38066552707294943, correlation after removing outliers: 0.3977847785318514,correlation changing: 0.017119251458901974
# fill nan instaed of outlier: False
#
#
# col: concavity_se, num of outliers: 22, Percentage of outliers: 3.8664323374340945 %
# p_value: 0.7775368037869802
# original correlation: 0.4703381344990796, correlation after removing outliers: 0.49779490215392147,correlation changing: 0.027456767654841896
# fill nan instaed of outlier: False
#
#
# col: concave points_se, num of outliers: 19, Percentage of outliers: 3.3391915641476277 %
# p_value: 0.899077679538182
# original correlation: 0.4887172830438194, correlation after removing outliers: 0.4927802186160092,correlation changing: 0.004062935572189785
# fill nan instaed of outlier: False
#
#
# col: symmetry_se, num of outliers: 27, Percentage of outliers: 4.745166959578207 %
# p_value: 0.5374734604398496
# original correlation: -0.09230343079467163, correlation after removing outliers: -0.14482794701000543,correlation changing: 0.0525245162153338
# fill nan instaed of outlier: False
#
#
# col: fractal_dimension_se, num of outliers: 28, Percentage of outliers: 4.92091388400703 %
# p_value: 0.49143742390333134
# original correlation: 0.20149167570094165, correlation after removing outliers: 0.22616829108349415,correlation changing: 0.024676615382552503
# fill nan instaed of outlier: False
#
#
# col: radius_worst, num of outliers: 17, Percentage of outliers: 2.987697715289982 %
# p_value: 0.9545546762482425
# original correlation: 0.7879329568959095, correlation after removing outliers: 0.7746877340040558,correlation changing: 0.013245222891853703
# fill nan instaed of outlier: False
#
#
# col: perimeter_worst, num of outliers: 15, Percentage of outliers: 2.6362038664323375 %
# p_value: 0.9856955377061442
# original correlation: 0.7963185971607477, correlation after removing outliers: 0.7853148493732172,correlation changing: 0.011003747787530549
# fill nan instaed of outlier: False
#
#
# col: area_worst, num of outliers: 35, Percentage of outliers: 6.151142355008787 %
# p_value: 0.2348509100165202
# original correlation: 0.786901907423319, correlation after removing outliers: 0.7564151796578362,correlation changing: 0.03048672776548278
# fill nan instaed of outlier: False
#
#
# col: compactness_worst, num of outliers: 16, Percentage of outliers: 2.8119507908611596 %
# p_value: 0.9730375373652475
# original correlation: 0.6068099168638246, correlation after removing outliers: 0.5817177634838896,correlation changing: 0.02509215337993498
# fill nan instaed of outlier: False
#
#
# col: concavity_worst, num of outliers: 12, Percentage of outliers: 2.10896309314587 %
# p_value: 0.999264526626596
# original correlation: 0.7057340103846973, correlation after removing outliers: 0.7041365493376495,correlation changing: 0.0015974610470478323
# fill nan instaed of outlier: False
#
#
# col: symmetry_worst, num of outliers: 23, Percentage of outliers: 4.042179261862917 %
# p_value: 0.7306474331966123
# original correlation: 0.3968427049401431, correlation after removing outliers: 0.3440035064235149,correlation changing: 0.052839198516628216
# fill nan instaed of outlier: False
#
#
# col: fractal_dimension_worst, num of outliers: 24, Percentage of outliers: 4.21792618629174 %
# p_value: 0.6823119689941686
# original correlation: 0.311476758890615, correlation after removing outliers: 0.27989718258320717,correlation changing: 0.03157957630740782
# fill nan instaed of outlier: False

# %% [markdown]
# ### Conclusion:
# ### Minimal Impact of Outliers: The analysis indicates that outliers have a minimal impact on the correlations between features and the target variable, as well as on the overall distributions. Therefore, it was decided not to remove them.
# ### Model Robustness: This suggests that your model may be robust to the presence of these outliers, or that the outliers themselves might represent valuable variations in the data that are worth keeping.

# %%
# check for null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int8
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), int8(1)
# memory usage: 138.5 KB

# %%
df.to_pickle('df_cleaned.pkl')
